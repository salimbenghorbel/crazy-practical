# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('logs2.csv', header = None)

# %%
data = data[(data.T != 0).any()]

# %%
data[0].plot()

# %%
data[1].plot()

# %%
data[2].plot()

# %%
data[3].plot()

# %%
data[0].plot()

# %%
diff = data[0]*1000 - data[3]

# %%
diff.plot()
